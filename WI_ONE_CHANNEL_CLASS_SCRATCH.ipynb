# %% [markdown]
# <a href="https://colab.research.google.com/github/agarr3/vajra/blob/main/WI_ONE_CHANNEL_CLASS_SCRATCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from tqdm import tqdm_notebook as tqdm
from sklearn.preprocessing import LabelEncoder
from PIL import Image
import matplotlib.pyplot as plt
import torch
# Neural networks can be constructed using the torch.nn package.
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset
import torchvision
import torchvision.transforms as transforms

import IPython.display as ipd

import random

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)

#settings
batch_size = 128
validation_split = .3
shuffle_dataset = True
random_seed= 42

criterion = nn.CrossEntropyLoss()


n_epochs = 30
print_every = 1

BASE_PATH = "/content/gdrive/My Drive/vajra/WI_CLASSIFIER/"
# Out:
# cuda:0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# DATA_BASE_PATH = "/content/gdrive/My Drive/Kaggle/GTZAN/Data/"
# DATA_SONG_DIR = "genres_original"
# DATA_IMG_DIR = "images_original"

# image = []
# labels = []
# songs = []

# for r,d, fileList in os.walk(DATA_BASE_PATH + DATA_SONG_DIR):
#   for file in fileList:
#     pre, ext = os.path.splitext(file)
#     # print(pre)
#     # print(file)
#     dir = r.split("/")[-1]
#     labels.append(dir)
#     # image.append(os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, r.split("/")[-1], pre.replace(".","")+".png"))
#     # songs.append(os.path.join(r,file))
#     image.append(pre.replace(".","")+".png")
#     songs.append(file)


# data = {'Images':image, "songs" :songs,'labels':labels} 
# data = pd.DataFrame(data) 
# data.head()

# %%
DATA_BASE_PATH = "/content/gdrive/"
DATA_SONG_DIR = "My Drive"
DATA_IMG_DIR = "My Drive"

files = []
exclusion = ["098567.npy","098569.npy", '098565.npy']
for r,d, fileList in os.walk("/content/gdrive/My Drive/Western_numpy"):
  for file in fileList:
    if(file not in exclusion):
      files.append([file,file, "Western_numpy"])
    else:
      print(file)

random.seed(1234)
files = random.sample(files, 2008)

for r,d, fileList in os.walk("/content/gdrive/My Drive/Indian_numpy"):
  for file in fileList:
    if(True):
      files.append([file,file, "Indian_numpy"])
    else:
      print(file)

data = pd.DataFrame(files, columns=['Images','songs','labels'])
#data = data.sample(frac=1).reset_index(drop=True)

print(len(data.index))
data.head()
# Out:
# 4016
#        Images       songs         labels
# 0  029351.npy  029351.npy  Western_numpy
# 1  093716.npy  093716.npy  Western_numpy
# 2  143217.npy  143217.npy  Western_numpy
# 3  131912.npy  131912.npy  Western_numpy
# 4  147059.npy  147059.npy  Western_numpy

# %%
data.groupby("labels").count()
# Out:
#                Images  songs
# labels
# Indian_numpy     2008   2008
# Western_numpy    2008   2008

# %%
test_idx = random. randint(0,1000)
# test_song = os.path.join(DATA_BASE_PATH, DATA_SONG_DIR, labels[test_idx], songs[test_idx])
# print(test_song)
# ipd.Audio(test_song) # load a local WAV file

# %%
test_img_path = os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, data.loc[test_idx, 'labels'], data.loc[test_idx, 'Images'])
print(test_img_path)
#ipd.Image(filename=test_img_path)
# test_image = Image.open(test_img_path)
# test_image = test_image.convert('RGB')
# test_image

numpy_arr = np.load(test_img_path)

array = numpy_arr*-1
print(array.max())
array *= (255.0/array.max())
array = 255 - array

test_image = Image.fromarray(array)
test_image = test_image.convert('L')
test_image = test_image.resize((300,300))
test_image
# Out:
# /content/gdrive/My Drive/Western_numpy/027855.npy
# 66.531906
# <PIL.Image.Image image mode=L size=300x300 at 0x7FC04C17AE90>

# %%
test_img_path = '/content/gdrive/My Drive/Kaggle/GTZAN/Data/images_original/reggae/reggae00016.png'
test_image = Image.open(test_img_path)
test_image = test_image.convert('RGB').convert('L')
test_image
# Out:
# <PIL.Image.Image image mode=L size=432x288 at 0x7FC04CF76710>

# %%
print(labels[test_idx])

tensorTrans = transforms.ToTensor()
test_image = tensorTrans(test_image)
test_image.shape

# %%
lb = LabelEncoder()
data['encoded_labels'] = lb.fit_transform(data['labels'])
data.head()
# Out:
#        Images       songs         labels  encoded_labels
# 0  029351.npy  029351.npy  Western_numpy               1
# 1  093716.npy  093716.npy  Western_numpy               1
# 2  143217.npy  143217.npy  Western_numpy               1
# 3  131912.npy  131912.npy  Western_numpy               1
# 4  147059.npy  147059.npy  Western_numpy               1

# %%
dataset_size = len(data)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# %%
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

# %%
transform_normal = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transform = transforms.Compose(
    [transforms.ToTensor()])

# %%
class IMG_Dataset(Dataset):
    def __init__(self, img_data,img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data
        
    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        img_name = os.path.join(self.img_path,self.img_data.loc[index, 'labels'],
                                self.img_data.loc[index, 'Images'])
        image = Image.open(img_name)
        image = image.convert('RGB').convert('L')
        #image = image.convert('RGB')
        #image = image.resize((300,300))
        label = torch.tensor(self.img_data.loc[index, 'encoded_labels'])
        if self.transform is not None:
            image = self.transform(image)
        return image, label

class MEL_Dataset(Dataset):
    def __init__(self, img_data,img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data
        
    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        img_name = os.path.join(self.img_path,self.img_data.loc[index, 'labels'],
                                self.img_data.loc[index, 'Images'])
        image = np.load(img_name)
        #image = image.convert('RGB').convert('L')
        #image = image.convert('RGB')
        #image = image.resize((300,300))
        label = torch.tensor(self.img_data.loc[index, 'encoded_labels'])
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
dataset = MEL_Dataset(data,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)

# %%
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                           sampler=train_sampler)
validation_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                sampler=valid_sampler)

# %%
data.groupby(by=['labels','encoded_labels']).count()
# Out:
#                               Images  songs
# labels        encoded_labels
# Indian_numpy  0                 2008   2008
# Western_numpy 1                 2008   2008

# %%
def img_display(img):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    npimg = np.transpose(npimg, (1, 2, 0))
    return npimg.squeeze()

def mel_display(S_DB):
    print(S_DB.shape)
    S_DB = S_DB.numpy()
    array = S_DB*-1
    print(array.max())
    array *= (255.0/array.max())
    array = 255 - array

    array = np.transpose(array, (1, 2, 0))
    return array.squeeze()

# %%
# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.imshow(mel_display(image)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label
# Out:
# torch.Size([1, 26, 400])
# 67.537994
# torch.Size([1, 26, 400])
# 58.63179
# torch.Size([1, 26, 400])
# 80.0
# torch.Size([1, 26, 400])
# 52.46012
# torch.Size([1, 26, 400])
# 69.964005
# torch.Size([1, 26, 400])
# 69.07929
# torch.Size([1, 26, 400])
# 59.41851
# torch.Size([1, 26, 400])
# 60.44189
# torch.Size([1, 26, 400])
# 76.99865
# torch.Size([1, 26, 400])
# 65.05542
# torch.Size([1, 26, 400])
# 54.35418
# torch.Size([1, 26, 400])
# 66.62348
# torch.Size([1, 26, 400])
# 65.39432
# torch.Size([1, 26, 400])
# 67.34591
# torch.Size([1, 26, 400])
# 40.737846

# %%
class SimpleCNNModel(nn.Module):
    def __init__(self):
        super(SimpleCNNModel, self).__init__()
        # 3 input image channel, 16 output channels, 3x3 square convolution kernel
        self.conv1 = nn.Conv2d(3,16,kernel_size=3,stride=2,padding=1)
        self.conv2 = nn.Conv2d(16, 32,kernel_size=3,stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 64,kernel_size=3,stride=2, padding=1)
        self.conv4 = nn.Conv2d(64, 64,kernel_size=3,stride=2, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout2d(0.4)
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.batchnorm3 = nn.BatchNorm2d(64)
        
        #self.fc1 = nn.Linear(64*5*5,512 )
        self.fc1 = nn.Linear(64*5*7,512 )
        
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        
    def forward(self, x):
        x = self.batchnorm1(F.relu(self.conv1(x)))
        x = self.batchnorm2(F.relu(self.conv2(x)))
        x = self.dropout(self.batchnorm2(self.pool(x)))
        x = self.batchnorm3(self.pool(F.relu(self.conv3(x))))
        x = self.dropout(self.conv4(x))
        #x = x.view(-1, 64*5*5) # Flatten layer
        x = x.view(-1, 64*5*7) # Flatten layer
        x = self.dropout(self.fc1(x))
        x = self.dropout(self.fc2(x))
        x = F.log_softmax(self.fc3(x),dim = 1)
        return x

# %%
class SimpleCNNModelOneChannel(nn.Module):
    def __init__(self):
        super(SimpleCNNModelOneChannel, self).__init__()
        # 3 input image channel, 16 output channels, 3x3 square convolution kernel
        self.conv1 = nn.Conv2d(1,16,kernel_size=3,stride=2,padding=1)
        self.conv2 = nn.Conv2d(16, 32,kernel_size=3,stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 64,kernel_size=3,stride=2, padding=1)
        self.conv4 = nn.Conv2d(64, 64,kernel_size=3,stride=2, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout2d(0.4)
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.batchnorm3 = nn.BatchNorm2d(64)
        
        #self.fc1 = nn.Linear(64*5*5,512 )
        self.fc1 = nn.Linear(384,512 )
        
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        
    def forward(self, x):
        x = self.batchnorm1(F.relu(self.conv1(x)))
        x = self.batchnorm2(F.relu(self.conv2(x)))
        x = self.dropout(self.batchnorm2(self.pool(x)))
        x = self.batchnorm3(self.pool(F.relu(self.conv3(x))))
        x = self.dropout(self.conv4(x))
        #x = x.view(-1, 64*5*5) # Flatten layer
        x = x.view(-1, 384) # Flatten layer
        x = self.dropout(self.fc1(x))
        x = self.dropout(self.fc2(x))
        x = F.log_softmax(self.fc3(x),dim = 1)
        return x

# %%
#model = SimpleCNNModel() # On CPU
#model = SimpleCNNModel().to(device)  # On GPU
model = SimpleCNNModelOneChannel().to(device)  # On GPU
print(model)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
# Out:
# SimpleCNNModelOneChannel(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout2d(p=0.4, inplace=False)
#   (batchnorm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=384, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
def accuracy(out, labels):
    _,pred = torch.max(out, dim=1)
    return torch.sum(pred==labels).item()

# %%
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader)
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    # scheduler.step(epoch)
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_loader):
        data_, target_ = data_.to(device), target_.to(device)# on GPU
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = model(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()
        # print statistics
        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % print_every == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\nepoch: {epoch}, train loss: {np.mean(train_loss):.4f}, train acc: {(100 * correct / total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        model.eval()
        for data_t, target_t in (validation_loader):
            data_t, target_t = data_t.to(device), target_t.to(device)# on GPU
            outputs_t = model(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t / total_t)
        val_loss.append(batch_loss/len(validation_loader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t / total_t):.4f}\n')
        # Saving the best weight 
        if network_learned:
            valid_loss_min = batch_loss
            torch.save(model.state_dict(), os.path.join(BASE_PATH, 'model_classification_tutorial.pt'))
            print('Detected network improvement, saving current model')
        
        fig = plt.figure(figsize=(20,10))
        plt.title("Train - Validation Loss")
        plt.plot( train_loss, label='train')
        plt.plot( val_loss, label='validation')
        plt.xlabel('num_epochs', fontsize=12)
        plt.ylabel('loss', fontsize=12)
        plt.legend(loc='best')
        plt.savefig(os.path.join(BASE_PATH, 'loss_plot.png'), bbox_inches='tight')

        fig = plt.figure(figsize=(20,10))
        plt.title("Train - Validation Accuracy")
        plt.plot(train_acc, label='train')
        plt.plot(val_acc, label='validation')
        plt.xlabel('num_epochs', fontsize=12)
        plt.ylabel('accuracy', fontsize=12)
        plt.legend(loc='best')
        plt.savefig(os.path.join(BASE_PATH, 'accuracy_plot.png'), bbox_inches='tight')

    model.train()
# Out:
# Epoch 1
#
# Epoch [1/30], Step [0/22], Loss: 2.3287
# Epoch [1/30], Step [1/22], Loss: 2.3221
# Epoch [1/30], Step [2/22], Loss: 2.3133
# Epoch [1/30], Step [3/22], Loss: 2.2939
# Epoch [1/30], Step [4/22], Loss: 2.2996
# Epoch [1/30], Step [5/22], Loss: 2.2737
# Epoch [1/30], Step [6/22], Loss: 2.2518
# Epoch [1/30], Step [7/22], Loss: 2.2364
# Epoch [1/30], Step [8/22], Loss: 2.2294
# Epoch [1/30], Step [9/22], Loss: 2.2318
# Epoch [1/30], Step [10/22], Loss: 2.2358
# Epoch [1/30], Step [11/22], Loss: 2.2038
# Epoch [1/30], Step [12/22], Loss: 2.1821
# Epoch [1/30], Step [13/22], Loss: 2.1885
# Epoch [1/30], Step [14/22], Loss: 2.1800
# Epoch [1/30], Step [15/22], Loss: 2.1532
# Epoch [1/30], Step [16/22], Loss: 2.1394
# Epoch [1/30], Step [17/22], Loss: 2.1637
# Epoch [1/30], Step [18/22], Loss: 2.1352
# Epoch [1/30], Step [19/22], Loss: 2.1167
# Epoch [1/30], Step [20/22], Loss: 2.1083
# Epoch [1/30], Step [21/22], Loss: 2.0894
#
# epoch: 1, train loss: 2.2126, train acc: 31.6856
# validation loss: 2.1175, validation acc: 51.7442
#
# Detected network improvement, saving current model
# Epoch 2
#
# Epoch [2/30], Step [0/22], Loss: 2.0682
# Epoch [2/30], Step [1/22], Loss: 2.0356
# Epoch [2/30], Step [2/22], Loss: 2.0451
# Epoch [2/30], Step [3/22], Loss: 2.0450
# Epoch [2/30], Step [4/22], Loss: 1.9673
# Epoch [2/30], Step [5/22], Loss: 1.9490
# Epoch [2/30], Step [6/22], Loss: 1.9922
# Epoch [2/30], Step [7/22], Loss: 1.9343
# Epoch [2/30], Step [8/22], Loss: 1.9242
# Epoch [2/30], Step [9/22], Loss: 1.9014
# Epoch [2/30], Step [10/22], Loss: 1.8383
# Epoch [2/30], Step [11/22], Loss: 1.9138
# Epoch [2/30], Step [12/22], Loss: 1.7899
# Epoch [2/30], Step [13/22], Loss: 1.7577
# Epoch [2/30], Step [14/22], Loss: 1.7835
# Epoch [2/30], Step [15/22], Loss: 1.6773
# Epoch [2/30], Step [16/22], Loss: 1.6464
# Epoch [2/30], Step [17/22], Loss: 1.6813
# Epoch [2/30], Step [18/22], Loss: 1.6434
# Epoch [2/30], Step [19/22], Loss: 1.5416
# Epoch [2/30], Step [20/22], Loss: 1.5612
# Epoch [2/30], Step [21/22], Loss: 1.5203
#
# epoch: 2, train loss: 2.0203, train acc: 65.0782
# validation loss: 1.9383, validation acc: 51.7442
#
# Detected network improvement, saving current model
# Epoch 3
#
# Epoch [3/30], Step [0/22], Loss: 1.4684
# Epoch [3/30], Step [1/22], Loss: 1.4268
# Epoch [3/30], Step [2/22], Loss: 1.3628
# Epoch [3/30], Step [3/22], Loss: 1.3852
# Epoch [3/30], Step [4/22], Loss: 1.3542
# Epoch [3/30], Step [5/22], Loss: 1.2260
# Epoch [3/30], Step [6/22], Loss: 1.2122
# Epoch [3/30], Step [7/22], Loss: 1.1601
# Epoch [3/30], Step [8/22], Loss: 1.1668
# Epoch [3/30], Step [9/22], Loss: 1.1830
# Epoch [3/30], Step [10/22], Loss: 1.0985
# Epoch [3/30], Step [11/22], Loss: 1.0771
# Epoch [3/30], Step [12/22], Loss: 1.0072
# Epoch [3/30], Step [13/22], Loss: 0.9771
# Epoch [3/30], Step [14/22], Loss: 0.8495
# Epoch [3/30], Step [15/22], Loss: 0.8131
# Epoch [3/30], Step [16/22], Loss: 0.7818
# Epoch [3/30], Step [17/22], Loss: 0.9316
# Epoch [3/30], Step [18/22], Loss: 0.7599
# Epoch [3/30], Step [19/22], Loss: 0.7451
# Epoch [3/30], Step [20/22], Loss: 0.7293
# Epoch [3/30], Step [21/22], Loss: 0.7728
#
# epoch: 3, train loss: 1.7028, train acc: 68.2432
# validation loss: 1.7710, validation acc: 51.7442
#
# Detected network improvement, saving current model
# Epoch 4
#
# Epoch [4/30], Step [0/22], Loss: 0.7039
# Epoch [4/30], Step [1/22], Loss: 0.7424
# Epoch [4/30], Step [2/22], Loss: 0.6623
# Epoch [4/30], Step [3/22], Loss: 0.6293
# Epoch [4/30], Step [4/22], Loss: 0.6586
# Epoch [4/30], Step [5/22], Loss: 0.7229
# Epoch [4/30], Step [6/22], Loss: 0.5647
# Epoch [4/30], Step [7/22], Loss: 0.6286
# Epoch [4/30], Step [8/22], Loss: 0.6106
# Epoch [4/30], Step [9/22], Loss: 0.6511
# Epoch [4/30], Step [10/22], Loss: 0.6564
# Epoch [4/30], Step [11/22], Loss: 0.5606
# Epoch [4/30], Step [12/22], Loss: 0.5777
# Epoch [4/30], Step [13/22], Loss: 0.6012
# Epoch [4/30], Step [14/22], Loss: 0.6826
# Epoch [4/30], Step [15/22], Loss: 0.5946
# Epoch [4/30], Step [16/22], Loss: 0.6010
# Epoch [4/30], Step [17/22], Loss: 0.6138
# Epoch [4/30], Step [18/22], Loss: 0.5759
# Epoch [4/30], Step [19/22], Loss: 0.5804
# Epoch [4/30], Step [20/22], Loss: 0.5840
# Epoch [4/30], Step [21/22], Loss: 0.6243
#
# epoch: 4, train loss: 1.4342, train acc: 71.3371
# validation loss: 1.5888, validation acc: 51.6611
#
# Detected network improvement, saving current model
# Epoch 5
#
# Epoch [5/30], Step [0/22], Loss: 0.5850
# Epoch [5/30], Step [1/22], Loss: 0.5405
# Epoch [5/30], Step [2/22], Loss: 0.5232
# Epoch [5/30], Step [3/22], Loss: 0.5889
# Epoch [5/30], Step [4/22], Loss: 0.4907
# Epoch [5/30], Step [5/22], Loss: 0.5734
# Epoch [5/30], Step [6/22], Loss: 0.5026
# Epoch [5/30], Step [7/22], Loss: 0.5963
# Epoch [5/30], Step [8/22], Loss: 0.4963
# Epoch [5/30], Step [9/22], Loss: 0.5036
# Epoch [5/30], Step [10/22], Loss: 0.5626
# Epoch [5/30], Step [11/22], Loss: 0.5576
# Epoch [5/30], Step [12/22], Loss: 0.6264
# Epoch [5/30], Step [13/22], Loss: 0.5283
# Epoch [5/30], Step [14/22], Loss: 0.4944
# Epoch [5/30], Step [15/22], Loss: 0.6119
# Epoch [5/30], Step [16/22], Loss: 0.6016
# Epoch [5/30], Step [17/22], Loss: 0.5222
# Epoch [5/30], Step [18/22], Loss: 0.5404
# Epoch [5/30], Step [19/22], Loss: 0.5455
# Epoch [5/30], Step [20/22], Loss: 0.4989
# Epoch [5/30], Step [21/22], Loss: 0.5694
#
# epoch: 5, train loss: 1.2570, train acc: 73.0441
# validation loss: 1.4652, validation acc: 51.7442
#
# Detected network improvement, saving current model
# Epoch 6
#
# Epoch [6/30], Step [0/22], Loss: 0.5764
# Epoch [6/30], Step [1/22], Loss: 0.5669
# Epoch [6/30], Step [2/22], Loss: 0.5041
# Epoch [6/30], Step [3/22], Loss: 0.5484
# Epoch [6/30], Step [4/22], Loss: 0.4594
# Epoch [6/30], Step [5/22], Loss: 0.6481
# Epoch [6/30], Step [6/22], Loss: 0.5216
# Epoch [6/30], Step [7/22], Loss: 0.4937
# Epoch [6/30], Step [8/22], Loss: 0.6054
# Epoch [6/30], Step [9/22], Loss: 0.5475
# Epoch [6/30], Step [10/22], Loss: 0.5550
# Epoch [6/30], Step [11/22], Loss: 0.4587
# Epoch [6/30], Step [12/22], Loss: 0.5637
# Epoch [6/30], Step [13/22], Loss: 0.5357
# Epoch [6/30], Step [14/22], Loss: 0.5030
# Epoch [6/30], Step [15/22], Loss: 0.5541
# Epoch [6/30], Step [16/22], Loss: 0.5520
# Epoch [6/30], Step [17/22], Loss: 0.4705
# Epoch [6/30], Step [18/22], Loss: 0.5475
# Epoch [6/30], Step [19/22], Loss: 0.5828
# Epoch [6/30], Step [20/22], Loss: 0.5405
# Epoch [6/30], Step [21/22], Loss: 0.6279
#
# epoch: 6, train loss: 1.1381, train acc: 73.8976
# validation loss: 1.3961, validation acc: 51.6611
#
# Epoch 7
#
# Epoch [7/30], Step [0/22], Loss: 0.5116
# Epoch [7/30], Step [1/22], Loss: 0.5122
# Epoch [7/30], Step [2/22], Loss: 0.5931
# Epoch [7/30], Step [3/22], Loss: 0.5440
# Epoch [7/30], Step [4/22], Loss: 0.4448
# Epoch [7/30], Step [5/22], Loss: 0.5106
# Epoch [7/30], Step [6/22], Loss: 0.4880
# Epoch [7/30], Step [7/22], Loss: 0.5794
# Epoch [7/30], Step [8/22], Loss: 0.5662
# Epoch [7/30], Step [9/22], Loss: 0.5640
# Epoch [7/30], Step [10/22], Loss: 0.5944
# Epoch [7/30], Step [11/22], Loss: 0.5036
# Epoch [7/30], Step [12/22], Loss: 0.5540
# Epoch [7/30], Step [13/22], Loss: 0.4767
# Epoch [7/30], Step [14/22], Loss: 0.5553
# Epoch [7/30], Step [15/22], Loss: 0.5110
# Epoch [7/30], Step [16/22], Loss: 0.6312
# Epoch [7/30], Step [17/22], Loss: 0.5559
# Epoch [7/30], Step [18/22], Loss: 0.5623
# Epoch [7/30], Step [19/22], Loss: 0.4694
# Epoch [7/30], Step [20/22], Loss: 0.5059
# Epoch [7/30], Step [21/22], Loss: 0.4789
#
# epoch: 7, train loss: 1.0516, train acc: 74.4666
# validation loss: 1.3364, validation acc: 51.6611
#
# Epoch 8
#
# Epoch [8/30], Step [0/22], Loss: 0.4848
# Epoch [8/30], Step [1/22], Loss: 0.5149
# Epoch [8/30], Step [2/22], Loss: 0.5089
# Epoch [8/30], Step [3/22], Loss: 0.4901
# Epoch [8/30], Step [4/22], Loss: 0.5968
# Epoch [8/30], Step [5/22], Loss: 0.5219
# Epoch [8/30], Step [6/22], Loss: 0.5278
# Epoch [8/30], Step [7/22], Loss: 0.5049
# Epoch [8/30], Step [8/22], Loss: 0.5185
# Epoch [8/30], Step [9/22], Loss: 0.4634
# Epoch [8/30], Step [10/22], Loss: 0.4753
# Epoch [8/30], Step [11/22], Loss: 0.5764
# Epoch [8/30], Step [12/22], Loss: 0.4228
# Epoch [8/30], Step [13/22], Loss: 0.5366
# Epoch [8/30], Step [14/22], Loss: 0.5249
# Epoch [8/30], Step [15/22], Loss: 0.5377
# Epoch [8/30], Step [16/22], Loss: 0.3799
# Epoch [8/30], Step [17/22], Loss: 0.4971
# Epoch [8/30], Step [18/22], Loss: 0.5264
# Epoch [8/30], Step [19/22], Loss: 0.5613
# Epoch [8/30], Step [20/22], Loss: 0.4675
# Epoch [8/30], Step [21/22], Loss: 0.5096
#
# epoch: 8, train loss: 0.9835, train acc: 75.8890
# validation loss: 1.3083, validation acc: 51.7442
#
# Epoch 9
#
# Epoch [9/30], Step [0/22], Loss: 0.4102
# Epoch [9/30], Step [1/22], Loss: 0.4828
# Epoch [9/30], Step [2/22], Loss: 0.4521
# Epoch [9/30], Step [3/22], Loss: 0.5437
# Epoch [9/30], Step [4/22], Loss: 0.4595
# Epoch [9/30], Step [5/22], Loss: 0.5340
# Epoch [9/30], Step [6/22], Loss: 0.4339
# Epoch [9/30], Step [7/22], Loss: 0.5251
# Epoch [9/30], Step [8/22], Loss: 0.5338
# Epoch [9/30], Step [9/22], Loss: 0.5105
# Epoch [9/30], Step [10/22], Loss: 0.4926
# Epoch [9/30], Step [11/22], Loss: 0.4324
# Epoch [9/30], Step [12/22], Loss: 0.5406
# Epoch [9/30], Step [13/22], Loss: 0.4661
# Epoch [9/30], Step [14/22], Loss: 0.5991
# Epoch [9/30], Step [15/22], Loss: 0.5374
# Epoch [9/30], Step [16/22], Loss: 0.5850
# Epoch [9/30], Step [17/22], Loss: 0.4978
# Epoch [9/30], Step [18/22], Loss: 0.5755
# Epoch [9/30], Step [19/22], Loss: 0.4963
# Epoch [9/30], Step [20/22], Loss: 0.4616
# Epoch [9/30], Step [21/22], Loss: 0.4138
#
# epoch: 9, train loss: 0.9297, train acc: 76.9559
# validation loss: 1.2761, validation acc: 51.6611
#
# Epoch 10
#
# Epoch [10/30], Step [0/22], Loss: 0.4242
# Epoch [10/30], Step [1/22], Loss: 0.4946
# Epoch [10/30], Step [2/22], Loss: 0.4510
# Epoch [10/30], Step [3/22], Loss: 0.4542
# Epoch [10/30], Step [4/22], Loss: 0.4251
# Epoch [10/30], Step [5/22], Loss: 0.5845
# Epoch [10/30], Step [6/22], Loss: 0.5345
# Epoch [10/30], Step [7/22], Loss: 0.4466
# Epoch [10/30], Step [8/22], Loss: 0.5079
# Epoch [10/30], Step [9/22], Loss: 0.5234
# Epoch [10/30], Step [10/22], Loss: 0.4803
# Epoch [10/30], Step [11/22], Loss: 0.5640
# Epoch [10/30], Step [12/22], Loss: 0.3749
# Epoch [10/30], Step [13/22], Loss: 0.4959
# Epoch [10/30], Step [14/22], Loss: 0.5209
# Epoch [10/30], Step [15/22], Loss: 0.4457
# Epoch [10/30], Step [16/22], Loss: 0.4326
# Epoch [10/30], Step [17/22], Loss: 0.4979
# Epoch [10/30], Step [18/22], Loss: 0.5007
# Epoch [10/30], Step [19/22], Loss: 0.4801
# Epoch [10/30], Step [20/22], Loss: 0.4924
# Epoch [10/30], Step [21/22], Loss: 0.4511
#
# epoch: 10, train loss: 0.8848, train acc: 77.3826
# validation loss: 1.2662, validation acc: 51.5781
#
# Epoch 11
#
# Epoch [11/30], Step [0/22], Loss: 0.4087
# Epoch [11/30], Step [1/22], Loss: 0.5289
# Epoch [11/30], Step [2/22], Loss: 0.4589
# Epoch [11/30], Step [3/22], Loss: 0.4982
# Epoch [11/30], Step [4/22], Loss: 0.4192
# Epoch [11/30], Step [5/22], Loss: 0.3922
# Epoch [11/30], Step [6/22], Loss: 0.4986
# Epoch [11/30], Step [7/22], Loss: 0.4304
# Epoch [11/30], Step [8/22], Loss: 0.4829
# Epoch [11/30], Step [9/22], Loss: 0.5285
# Epoch [11/30], Step [10/22], Loss: 0.4599
# Epoch [11/30], Step [11/22], Loss: 0.5243
# Epoch [11/30], Step [12/22], Loss: 0.4795
# Epoch [11/30], Step [13/22], Loss: 0.4779
# Epoch [11/30], Step [14/22], Loss: 0.3802
# Epoch [11/30], Step [15/22], Loss: 0.4248
# Epoch [11/30], Step [16/22], Loss: 0.4795
# Epoch [11/30], Step [17/22], Loss: 0.4735
# Epoch [11/30], Step [18/22], Loss: 0.4080
# Epoch [11/30], Step [19/22], Loss: 0.5709
# Epoch [11/30], Step [20/22], Loss: 0.3494
# Epoch [11/30], Step [21/22], Loss: 0.4562
#
# epoch: 11, train loss: 0.8462, train acc: 78.8051
# validation loss: 1.2714, validation acc: 51.6611
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Epoch 12
#
# Epoch [12/30], Step [0/22], Loss: 0.4827
# Epoch [12/30], Step [1/22], Loss: 0.4779
# Epoch [12/30], Step [2/22], Loss: 0.4528
# Epoch [12/30], Step [3/22], Loss: 0.4933
# Epoch [12/30], Step [4/22], Loss: 0.4733
# Epoch [12/30], Step [5/22], Loss: 0.4057
# Epoch [12/30], Step [6/22], Loss: 0.4490
# Epoch [12/30], Step [7/22], Loss: 0.4579
# Epoch [12/30], Step [8/22], Loss: 0.4667
# Epoch [12/30], Step [9/22], Loss: 0.4078
# Epoch [12/30], Step [10/22], Loss: 0.4246
# Epoch [12/30], Step [11/22], Loss: 0.3923
# Epoch [12/30], Step [12/22], Loss: 0.5395
# Epoch [12/30], Step [13/22], Loss: 0.4743
# Epoch [12/30], Step [14/22], Loss: 0.4267
# Epoch [12/30], Step [15/22], Loss: 0.4253
# Epoch [12/30], Step [16/22], Loss: 0.4349
# Epoch [12/30], Step [17/22], Loss: 0.4094
# Epoch [12/30], Step [18/22], Loss: 0.4098
# Epoch [12/30], Step [19/22], Loss: 0.4578
# Epoch [12/30], Step [20/22], Loss: 0.4219
# Epoch [12/30], Step [21/22], Loss: 0.4178
#
# epoch: 12, train loss: 0.8128, train acc: 79.3030
# validation loss: 1.2741, validation acc: 51.5781
#
# Epoch 13
#
# Epoch [13/30], Step [0/22], Loss: 0.5063
# Epoch [13/30], Step [1/22], Loss: 0.4550
# Epoch [13/30], Step [2/22], Loss: 0.4419
# Epoch [13/30], Step [3/22], Loss: 0.4826
# Epoch [13/30], Step [4/22], Loss: 0.4512
# Epoch [13/30], Step [5/22], Loss: 0.3905
# Epoch [13/30], Step [6/22], Loss: 0.4417
# Epoch [13/30], Step [7/22], Loss: 0.3808
# Epoch [13/30], Step [8/22], Loss: 0.5587
# Epoch [13/30], Step [9/22], Loss: 0.3429
# Epoch [13/30], Step [10/22], Loss: 0.4737
# Epoch [13/30], Step [11/22], Loss: 0.4326
# Epoch [13/30], Step [12/22], Loss: 0.4707
# Epoch [13/30], Step [13/22], Loss: 0.5094
# Epoch [13/30], Step [14/22], Loss: 0.4934
# Epoch [13/30], Step [15/22], Loss: 0.4667
# Epoch [13/30], Step [16/22], Loss: 0.4609
# Epoch [13/30], Step [17/22], Loss: 0.4222
# Epoch [13/30], Step [18/22], Loss: 0.4838
# Epoch [13/30], Step [19/22], Loss: 0.4484
# Epoch [13/30], Step [20/22], Loss: 0.4756
# Epoch [13/30], Step [21/22], Loss: 0.4183
#
# epoch: 13, train loss: 0.7853, train acc: 79.5164
# validation loss: 1.2731, validation acc: 51.5781
#
# Epoch 14
#
# Epoch [14/30], Step [0/22], Loss: 0.4467
# Epoch [14/30], Step [1/22], Loss: 0.4767
# Epoch [14/30], Step [2/22], Loss: 0.4536
# Epoch [14/30], Step [3/22], Loss: 0.4355
# Epoch [14/30], Step [4/22], Loss: 0.4533
# Epoch [14/30], Step [5/22], Loss: 0.3958
# Epoch [14/30], Step [6/22], Loss: 0.4743
# Epoch [14/30], Step [7/22], Loss: 0.3868
# Epoch [14/30], Step [8/22], Loss: 0.4894
# Epoch [14/30], Step [9/22], Loss: 0.4352
# Epoch [14/30], Step [10/22], Loss: 0.4347
# Epoch [14/30], Step [11/22], Loss: 0.3544
# Epoch [14/30], Step [12/22], Loss: 0.4894
# Epoch [14/30], Step [13/22], Loss: 0.4211
# Epoch [14/30], Step [14/22], Loss: 0.3681
# Epoch [14/30], Step [15/22], Loss: 0.4262
# Epoch [14/30], Step [16/22], Loss: 0.3548
# Epoch [14/30], Step [17/22], Loss: 0.3772
# Epoch [14/30], Step [18/22], Loss: 0.4639
# Epoch [14/30], Step [19/22], Loss: 0.4484
# Epoch [14/30], Step [20/22], Loss: 0.3961
# Epoch [14/30], Step [21/22], Loss: 0.4977
#
# epoch: 14, train loss: 0.7600, train acc: 81.0100
# validation loss: 1.2792, validation acc: 51.5781
#
# Epoch 15
#
# Epoch [15/30], Step [0/22], Loss: 0.3928
# Epoch [15/30], Step [1/22], Loss: 0.3755
# Epoch [15/30], Step [2/22], Loss: 0.3882
# Epoch [15/30], Step [3/22], Loss: 0.5064
# Epoch [15/30], Step [4/22], Loss: 0.4752
# Epoch [15/30], Step [5/22], Loss: 0.3609
# Epoch [15/30], Step [6/22], Loss: 0.4440
# Epoch [15/30], Step [7/22], Loss: 0.4117
# Epoch [15/30], Step [8/22], Loss: 0.5763
# Epoch [15/30], Step [9/22], Loss: 0.3504
# Epoch [15/30], Step [10/22], Loss: 0.3936
# Epoch [15/30], Step [11/22], Loss: 0.3865
# Epoch [15/30], Step [12/22], Loss: 0.3813
# Epoch [15/30], Step [13/22], Loss: 0.4150
# Epoch [15/30], Step [14/22], Loss: 0.4648
# Epoch [15/30], Step [15/22], Loss: 0.3627
# Epoch [15/30], Step [16/22], Loss: 0.4076
# Epoch [15/30], Step [17/22], Loss: 0.4627
# Epoch [15/30], Step [18/22], Loss: 0.3624
# Epoch [15/30], Step [19/22], Loss: 0.4999
# Epoch [15/30], Step [20/22], Loss: 0.3968
# Epoch [15/30], Step [21/22], Loss: 0.3634
#
# epoch: 15, train loss: 0.7371, train acc: 81.4367
# validation loss: 1.2783, validation acc: 51.5781
#
# Epoch 16
#
# Epoch [16/30], Step [0/22], Loss: 0.4776
# Epoch [16/30], Step [1/22], Loss: 0.4378
# Epoch [16/30], Step [2/22], Loss: 0.3793
# Epoch [16/30], Step [3/22], Loss: 0.3491
# Epoch [16/30], Step [4/22], Loss: 0.4924
# Epoch [16/30], Step [5/22], Loss: 0.4653
# Epoch [16/30], Step [6/22], Loss: 0.3869
# Epoch [16/30], Step [7/22], Loss: 0.3760
# Epoch [16/30], Step [8/22], Loss: 0.4969
# Epoch [16/30], Step [9/22], Loss: 0.3462
# Epoch [16/30], Step [10/22], Loss: 0.3201
# Epoch [16/30], Step [11/22], Loss: 0.3135
# Epoch [16/30], Step [12/22], Loss: 0.4756
# Epoch [16/30], Step [13/22], Loss: 0.3118
# Epoch [16/30], Step [14/22], Loss: 0.4277
# Epoch [16/30], Step [15/22], Loss: 0.3535
# Epoch [16/30], Step [16/22], Loss: 0.3611
# Epoch [16/30], Step [17/22], Loss: 0.3824
# Epoch [16/30], Step [18/22], Loss: 0.4688
# Epoch [16/30], Step [19/22], Loss: 0.4278
# Epoch [16/30], Step [20/22], Loss: 0.5458
# Epoch [16/30], Step [21/22], Loss: 0.4259
#
# epoch: 16, train loss: 0.7167, train acc: 82.9303
# validation loss: 1.2957, validation acc: 51.5781
#
# Epoch 17
#
# Epoch [17/30], Step [0/22], Loss: 0.4264
# Epoch [17/30], Step [1/22], Loss: 0.3701
# Epoch [17/30], Step [2/22], Loss: 0.3652
# Epoch [17/30], Step [3/22], Loss: 0.3280
# Epoch [17/30], Step [4/22], Loss: 0.4500
# Epoch [17/30], Step [5/22], Loss: 0.4060
# Epoch [17/30], Step [6/22], Loss: 0.4225
# Epoch [17/30], Step [7/22], Loss: 0.4435
# Epoch [17/30], Step [8/22], Loss: 0.4255
# Epoch [17/30], Step [9/22], Loss: 0.3630
# Epoch [17/30], Step [10/22], Loss: 0.3677
# Epoch [17/30], Step [11/22], Loss: 0.3512
# Epoch [17/30], Step [12/22], Loss: 0.3037
# Epoch [17/30], Step [13/22], Loss: 0.4055
# Epoch [17/30], Step [14/22], Loss: 0.4396
# Epoch [17/30], Step [15/22], Loss: 0.4241
# Epoch [17/30], Step [16/22], Loss: 0.4709
# Epoch [17/30], Step [17/22], Loss: 0.4180
# Epoch [17/30], Step [18/22], Loss: 0.4375
# Epoch [17/30], Step [19/22], Loss: 0.5164
# Epoch [17/30], Step [20/22], Loss: 0.4313
# Epoch [17/30], Step [21/22], Loss: 0.3900
#
# epoch: 17, train loss: 0.6985, train acc: 82.0413
# validation loss: 1.3038, validation acc: 51.5781
#
# Epoch 18
#
# Epoch [18/30], Step [0/22], Loss: 0.4626
# Epoch [18/30], Step [1/22], Loss: 0.3263
# Epoch [18/30], Step [2/22], Loss: 0.3915
# Epoch [18/30], Step [3/22], Loss: 0.3894
# Epoch [18/30], Step [4/22], Loss: 0.4373
# Epoch [18/30], Step [5/22], Loss: 0.3546
# Epoch [18/30], Step [6/22], Loss: 0.4353
# Epoch [18/30], Step [7/22], Loss: 0.5356
# Epoch [18/30], Step [8/22], Loss: 0.3530
# Epoch [18/30], Step [9/22], Loss: 0.3627
# Epoch [18/30], Step [10/22], Loss: 0.2740
# Epoch [18/30], Step [11/22], Loss: 0.3666
# Epoch [18/30], Step [12/22], Loss: 0.3676
# Epoch [18/30], Step [13/22], Loss: 0.4338
# Epoch [18/30], Step [14/22], Loss: 0.4009
# Epoch [18/30], Step [15/22], Loss: 0.3708
# Epoch [18/30], Step [16/22], Loss: 0.3317
# Epoch [18/30], Step [17/22], Loss: 0.3449
# Epoch [18/30], Step [18/22], Loss: 0.3792
# Epoch [18/30], Step [19/22], Loss: 0.4169
# Epoch [18/30], Step [20/22], Loss: 0.3549
# Epoch [18/30], Step [21/22], Loss: 0.4458
#
# epoch: 18, train loss: 0.6812, train acc: 83.1081
# validation loss: 1.3190, validation acc: 51.5781
#
# Epoch 19
#
# Epoch [19/30], Step [0/22], Loss: 0.3365
# Epoch [19/30], Step [1/22], Loss: 0.3464
# Epoch [19/30], Step [2/22], Loss: 0.3848
# Epoch [19/30], Step [3/22], Loss: 0.4552
# Epoch [19/30], Step [4/22], Loss: 0.3572
# Epoch [19/30], Step [5/22], Loss: 0.3996
# Epoch [19/30], Step [6/22], Loss: 0.3937
# Epoch [19/30], Step [7/22], Loss: 0.3000
# Epoch [19/30], Step [8/22], Loss: 0.3878
# Epoch [19/30], Step [9/22], Loss: 0.3946
# Epoch [19/30], Step [10/22], Loss: 0.2857
# Epoch [19/30], Step [11/22], Loss: 0.4675
# Epoch [19/30], Step [12/22], Loss: 0.3998
# Epoch [19/30], Step [13/22], Loss: 0.4618
# Epoch [19/30], Step [14/22], Loss: 0.3991
# Epoch [19/30], Step [15/22], Loss: 0.3819
# Epoch [19/30], Step [16/22], Loss: 0.2780
# Epoch [19/30], Step [17/22], Loss: 0.3515
# Epoch [19/30], Step [18/22], Loss: 0.4252
# Epoch [19/30], Step [19/22], Loss: 0.3529
# Epoch [19/30], Step [20/22], Loss: 0.4102
# Epoch [19/30], Step [21/22], Loss: 0.3403
#
# epoch: 19, train loss: 0.6653, train acc: 83.8905
# validation loss: 1.3328, validation acc: 51.5781
#
# Epoch 20
#
# Epoch [20/30], Step [0/22], Loss: 0.3475
# Epoch [20/30], Step [1/22], Loss: 0.3917
# Epoch [20/30], Step [2/22], Loss: 0.3926
# Epoch [20/30], Step [3/22], Loss: 0.3549
# Epoch [20/30], Step [4/22], Loss: 0.3851
# Epoch [20/30], Step [5/22], Loss: 0.3613
# Epoch [20/30], Step [6/22], Loss: 0.3531
# Epoch [20/30], Step [7/22], Loss: 0.3500
# Epoch [20/30], Step [8/22], Loss: 0.4177
# Epoch [20/30], Step [9/22], Loss: 0.3211
# Epoch [20/30], Step [10/22], Loss: 0.3248
# Epoch [20/30], Step [11/22], Loss: 0.3831
# Epoch [20/30], Step [12/22], Loss: 0.3646
# Epoch [20/30], Step [13/22], Loss: 0.3422
# Epoch [20/30], Step [14/22], Loss: 0.3842
# Epoch [20/30], Step [15/22], Loss: 0.3518
# Epoch [20/30], Step [16/22], Loss: 0.3556
# Epoch [20/30], Step [17/22], Loss: 0.3869
# Epoch [20/30], Step [18/22], Loss: 0.3673
# Epoch [20/30], Step [19/22], Loss: 0.3511
# Epoch [20/30], Step [20/22], Loss: 0.3936
# Epoch [20/30], Step [21/22], Loss: 0.3835
#
# epoch: 20, train loss: 0.6503, train acc: 84.1750
# validation loss: 1.3419, validation acc: 51.5781
#
# Epoch 21
#
# Epoch [21/30], Step [0/22], Loss: 0.3925
# Epoch [21/30], Step [1/22], Loss: 0.3367
# Epoch [21/30], Step [2/22], Loss: 0.2939
# Epoch [21/30], Step [3/22], Loss: 0.3644
# Epoch [21/30], Step [4/22], Loss: 0.4389
# Epoch [21/30], Step [5/22], Loss: 0.3647
# Epoch [21/30], Step [6/22], Loss: 0.2603
# Epoch [21/30], Step [7/22], Loss: 0.3405
# Epoch [21/30], Step [8/22], Loss: 0.5149
# Epoch [21/30], Step [9/22], Loss: 0.3643
# Epoch [21/30], Step [10/22], Loss: 0.4141
# Epoch [21/30], Step [11/22], Loss: 0.3873
# Epoch [21/30], Step [12/22], Loss: 0.3188
# Epoch [21/30], Step [13/22], Loss: 0.3120
# Epoch [21/30], Step [14/22], Loss: 0.2613
# Epoch [21/30], Step [15/22], Loss: 0.2767
# Epoch [21/30], Step [16/22], Loss: 0.4173
# Epoch [21/30], Step [17/22], Loss: 0.3049
# Epoch [21/30], Step [18/22], Loss: 0.2851
# Epoch [21/30], Step [19/22], Loss: 0.4372
# Epoch [21/30], Step [20/22], Loss: 0.3149
# Epoch [21/30], Step [21/22], Loss: 0.3937
#
# epoch: 21, train loss: 0.6362, train acc: 85.2063
# validation loss: 1.3679, validation acc: 51.6611
#
# Epoch 22
#
# Epoch [22/30], Step [0/22], Loss: 0.3013
# Epoch [22/30], Step [1/22], Loss: 0.4156
# Epoch [22/30], Step [2/22], Loss: 0.2838
# Epoch [22/30], Step [3/22], Loss: 0.3403
# Epoch [22/30], Step [4/22], Loss: 0.3787
# Epoch [22/30], Step [5/22], Loss: 0.3756
# Epoch [22/30], Step [6/22], Loss: 0.4463
# Epoch [22/30], Step [7/22], Loss: 0.3507
# Epoch [22/30], Step [8/22], Loss: 0.3555
# Epoch [22/30], Step [9/22], Loss: 0.3142
# Epoch [22/30], Step [10/22], Loss: 0.3813
# Epoch [22/30], Step [11/22], Loss: 0.3162
# Epoch [22/30], Step [12/22], Loss: 0.2850
# Epoch [22/30], Step [13/22], Loss: 0.3487
# Epoch [22/30], Step [14/22], Loss: 0.3905
# Epoch [22/30], Step [15/22], Loss: 0.3552
# Epoch [22/30], Step [16/22], Loss: 0.4516
# Epoch [22/30], Step [17/22], Loss: 0.3377
# Epoch [22/30], Step [18/22], Loss: 0.3455
# Epoch [22/30], Step [19/22], Loss: 0.3356
# Epoch [22/30], Step [20/22], Loss: 0.3976
# Epoch [22/30], Step [21/22], Loss: 0.3837
#
# epoch: 22, train loss: 0.6236, train acc: 84.8151
# validation loss: 1.3822, validation acc: 51.6611
#
# Epoch 23
#
# Epoch [23/30], Step [0/22], Loss: 0.3387
# Epoch [23/30], Step [1/22], Loss: 0.3793
# Epoch [23/30], Step [2/22], Loss: 0.3913
# Epoch [23/30], Step [3/22], Loss: 0.4203
# Epoch [23/30], Step [4/22], Loss: 0.2867
# Epoch [23/30], Step [5/22], Loss: 0.3542
# Epoch [23/30], Step [6/22], Loss: 0.3597
# Epoch [23/30], Step [7/22], Loss: 0.2374
# Epoch [23/30], Step [8/22], Loss: 0.3848
# Epoch [23/30], Step [9/22], Loss: 0.3319
# Epoch [23/30], Step [10/22], Loss: 0.2811
# Epoch [23/30], Step [11/22], Loss: 0.2764
# Epoch [23/30], Step [12/22], Loss: 0.3107
# Epoch [23/30], Step [13/22], Loss: 0.3124
# Epoch [23/30], Step [14/22], Loss: 0.2629
# Epoch [23/30], Step [15/22], Loss: 0.4256
# Epoch [23/30], Step [16/22], Loss: 0.4307
# Epoch [23/30], Step [17/22], Loss: 0.3041
# Epoch [23/30], Step [18/22], Loss: 0.3210
# Epoch [23/30], Step [19/22], Loss: 0.3128
# Epoch [23/30], Step [20/22], Loss: 0.4215
# Epoch [23/30], Step [21/22], Loss: 0.3732
#
# epoch: 23, train loss: 0.6114, train acc: 85.6330
# validation loss: 1.4145, validation acc: 51.6611
#
# Epoch 24
#
# Epoch [24/30], Step [0/22], Loss: 0.5016
# Epoch [24/30], Step [1/22], Loss: 0.3079
# Epoch [24/30], Step [2/22], Loss: 0.3310
# Epoch [24/30], Step [3/22], Loss: 0.3716
# Epoch [24/30], Step [4/22], Loss: 0.2915
# Epoch [24/30], Step [5/22], Loss: 0.3038
# Epoch [24/30], Step [6/22], Loss: 0.3572
# Epoch [24/30], Step [7/22], Loss: 0.3443
# Epoch [24/30], Step [8/22], Loss: 0.3920
# Epoch [24/30], Step [9/22], Loss: 0.3322
# Epoch [24/30], Step [10/22], Loss: 0.3266
# Epoch [24/30], Step [11/22], Loss: 0.3129
# Epoch [24/30], Step [12/22], Loss: 0.2555
# Epoch [24/30], Step [13/22], Loss: 0.2618
# Epoch [24/30], Step [14/22], Loss: 0.3508
# Epoch [24/30], Step [15/22], Loss: 0.6299
# Epoch [24/30], Step [16/22], Loss: 0.3099
# Epoch [24/30], Step [17/22], Loss: 0.3080
# Epoch [24/30], Step [18/22], Loss: 0.3789
# Epoch [24/30], Step [19/22], Loss: 0.3045
# Epoch [24/30], Step [20/22], Loss: 0.3276
# Epoch [24/30], Step [21/22], Loss: 0.3526
#
# epoch: 24, train loss: 0.6004, train acc: 85.3841
# validation loss: 1.4364, validation acc: 51.6611
#
# Epoch 25
#
# Epoch [25/30], Step [0/22], Loss: 0.2619
# Epoch [25/30], Step [1/22], Loss: 0.3521
# Epoch [25/30], Step [2/22], Loss: 0.3400
# Epoch [25/30], Step [3/22], Loss: 0.3297
# Epoch [25/30], Step [4/22], Loss: 0.3240
# Epoch [25/30], Step [5/22], Loss: 0.3288
# Epoch [25/30], Step [6/22], Loss: 0.4219
# Epoch [25/30], Step [7/22], Loss: 0.2905
# Epoch [25/30], Step [8/22], Loss: 0.3767
# Epoch [25/30], Step [9/22], Loss: 0.3294
# Epoch [25/30], Step [10/22], Loss: 0.3564
# Epoch [25/30], Step [11/22], Loss: 0.3779
# Epoch [25/30], Step [12/22], Loss: 0.2978
# Epoch [25/30], Step [13/22], Loss: 0.2353
# Epoch [25/30], Step [14/22], Loss: 0.3100
# Epoch [25/30], Step [15/22], Loss: 0.3275
# Epoch [25/30], Step [16/22], Loss: 0.2795
# Epoch [25/30], Step [17/22], Loss: 0.3061
# Epoch [25/30], Step [18/22], Loss: 0.2985
# Epoch [25/30], Step [19/22], Loss: 0.3797
# Epoch [25/30], Step [20/22], Loss: 0.3730
# Epoch [25/30], Step [21/22], Loss: 0.3130
#
# epoch: 25, train loss: 0.5895, train acc: 85.9886
# validation loss: 1.4544, validation acc: 51.6611
#
# Epoch 26
#
# Epoch [26/30], Step [0/22], Loss: 0.4261
# Epoch [26/30], Step [1/22], Loss: 0.2892
# Epoch [26/30], Step [2/22], Loss: 0.4400
# Epoch [26/30], Step [3/22], Loss: 0.4085
# Epoch [26/30], Step [4/22], Loss: 0.3928
# Epoch [26/30], Step [5/22], Loss: 0.3697
# Epoch [26/30], Step [6/22], Loss: 0.3826
# Epoch [26/30], Step [7/22], Loss: 0.3084
# Epoch [26/30], Step [8/22], Loss: 0.2900
# Epoch [26/30], Step [9/22], Loss: 0.3387
# Epoch [26/30], Step [10/22], Loss: 0.2435
# Epoch [26/30], Step [11/22], Loss: 0.3723
# Epoch [26/30], Step [12/22], Loss: 0.2701
# Epoch [26/30], Step [13/22], Loss: 0.2652
# Epoch [26/30], Step [14/22], Loss: 0.2875
# Epoch [26/30], Step [15/22], Loss: 0.2844
# Epoch [26/30], Step [16/22], Loss: 0.2801
# Epoch [26/30], Step [17/22], Loss: 0.2823
# Epoch [26/30], Step [18/22], Loss: 0.3754
# Epoch [26/30], Step [19/22], Loss: 0.3563
# Epoch [26/30], Step [20/22], Loss: 0.2442
# Epoch [26/30], Step [21/22], Loss: 0.2578
#
# epoch: 26, train loss: 0.5793, train acc: 86.3087
# validation loss: 1.4816, validation acc: 51.6611
#
# Epoch 27
#
# Epoch [27/30], Step [0/22], Loss: 0.3325
# Epoch [27/30], Step [1/22], Loss: 0.3055
# Epoch [27/30], Step [2/22], Loss: 0.2554
# Epoch [27/30], Step [3/22], Loss: 0.2597
# Epoch [27/30], Step [4/22], Loss: 0.3007
# Epoch [27/30], Step [5/22], Loss: 0.2679
# Epoch [27/30], Step [6/22], Loss: 0.3214
# Epoch [27/30], Step [7/22], Loss: 0.3435
# Epoch [27/30], Step [8/22], Loss: 0.3736
# Epoch [27/30], Step [9/22], Loss: 0.2690
# Epoch [27/30], Step [10/22], Loss: 0.3067
# Epoch [27/30], Step [11/22], Loss: 0.2933
# Epoch [27/30], Step [12/22], Loss: 0.3183
# Epoch [27/30], Step [13/22], Loss: 0.3908
# Epoch [27/30], Step [14/22], Loss: 0.4645
# Epoch [27/30], Step [15/22], Loss: 0.3712
# Epoch [27/30], Step [16/22], Loss: 0.3073
# Epoch [27/30], Step [17/22], Loss: 0.3636
# Epoch [27/30], Step [18/22], Loss: 0.3335
# Epoch [27/30], Step [19/22], Loss: 0.3448
# Epoch [27/30], Step [20/22], Loss: 0.3435
# Epoch [27/30], Step [21/22], Loss: 0.3181
#
# epoch: 27, train loss: 0.5700, train acc: 86.2376
# validation loss: 1.5138, validation acc: 51.6611
#
# Epoch 28
#
# Epoch [28/30], Step [0/22], Loss: 0.3818
# Epoch [28/30], Step [1/22], Loss: 0.3178
# Epoch [28/30], Step [2/22], Loss: 0.2884
# Epoch [28/30], Step [3/22], Loss: 0.3482
# Epoch [28/30], Step [4/22], Loss: 0.2915
# Epoch [28/30], Step [5/22], Loss: 0.3405
# Epoch [28/30], Step [6/22], Loss: 0.2735
# Epoch [28/30], Step [7/22], Loss: 0.3681
# Epoch [28/30], Step [8/22], Loss: 0.3325
# Epoch [28/30], Step [9/22], Loss: 0.3185
# Epoch [28/30], Step [10/22], Loss: 0.3591
# Epoch [28/30], Step [11/22], Loss: 0.3282
# Epoch [28/30], Step [12/22], Loss: 0.2511
# Epoch [28/30], Step [13/22], Loss: 0.3164
# Epoch [28/30], Step [14/22], Loss: 0.3775
# Epoch [28/30], Step [15/22], Loss: 0.3015
# Epoch [28/30], Step [16/22], Loss: 0.2248
# Epoch [28/30], Step [17/22], Loss: 0.3275
# Epoch [28/30], Step [18/22], Loss: 0.2807
# Epoch [28/30], Step [19/22], Loss: 0.3352
# Epoch [28/30], Step [20/22], Loss: 0.3378
# Epoch [28/30], Step [21/22], Loss: 0.2903
#
# epoch: 28, train loss: 0.5610, train acc: 86.1664
# validation loss: 1.5451, validation acc: 51.6611
#
# Epoch 29
#
# Epoch [29/30], Step [0/22], Loss: 0.3153
# Epoch [29/30], Step [1/22], Loss: 0.3784
# Epoch [29/30], Step [2/22], Loss: 0.2648
# Epoch [29/30], Step [3/22], Loss: 0.2182
# Epoch [29/30], Step [4/22], Loss: 0.3269
# Epoch [29/30], Step [5/22], Loss: 0.3867
# Epoch [29/30], Step [6/22], Loss: 0.2709
# Epoch [29/30], Step [7/22], Loss: 0.3189
# Epoch [29/30], Step [8/22], Loss: 0.2628
# Epoch [29/30], Step [9/22], Loss: 0.2627
# Epoch [29/30], Step [10/22], Loss: 0.4440
# Epoch [29/30], Step [11/22], Loss: 0.3081
# Epoch [29/30], Step [12/22], Loss: 0.2877
# Epoch [29/30], Step [13/22], Loss: 0.3262
# Epoch [29/30], Step [14/22], Loss: 0.2789
# Epoch [29/30], Step [15/22], Loss: 0.2737
# Epoch [29/30], Step [16/22], Loss: 0.3013
# Epoch [29/30], Step [17/22], Loss: 0.3199
# Epoch [29/30], Step [18/22], Loss: 0.2867
# Epoch [29/30], Step [19/22], Loss: 0.2650
# Epoch [29/30], Step [20/22], Loss: 0.2647
# Epoch [29/30], Step [21/22], Loss: 0.3258
#
# epoch: 29, train loss: 0.5521, train acc: 87.1977
# validation loss: 1.5632, validation acc: 51.6611
#
# Epoch 30
#
# Epoch [30/30], Step [0/22], Loss: 0.2560
# Epoch [30/30], Step [1/22], Loss: 0.3795
# Epoch [30/30], Step [2/22], Loss: 0.2914
# Epoch [30/30], Step [3/22], Loss: 0.2779
# Epoch [30/30], Step [4/22], Loss: 0.3110
# Epoch [30/30], Step [5/22], Loss: 0.2212
# Epoch [30/30], Step [6/22], Loss: 0.3646
# Epoch [30/30], Step [7/22], Loss: 0.3189
# Epoch [30/30], Step [8/22], Loss: 0.3183
# Epoch [30/30], Step [9/22], Loss: 0.2786
# Epoch [30/30], Step [10/22], Loss: 0.1931
# Epoch [30/30], Step [11/22], Loss: 0.3194
# Epoch [30/30], Step [12/22], Loss: 0.2466
# Epoch [30/30], Step [13/22], Loss: 0.3556
# Epoch [30/30], Step [14/22], Loss: 0.3405
# Epoch [30/30], Step [15/22], Loss: 0.3025
# Epoch [30/30], Step [16/22], Loss: 0.2408
# Epoch [30/30], Step [17/22], Loss: 0.3071
# Epoch [30/30], Step [18/22], Loss: 0.2752
# Epoch [30/30], Step [19/22], Loss: 0.3422
# Epoch [30/30], Step [20/22], Loss: 0.2917
# Epoch [30/30], Step [21/22], Loss: 0.2892
#
# epoch: 30, train loss: 0.5436, train acc: 87.9445
# validation loss: 1.5899, validation acc: 51.6611

# %%
model.load_state_dict(torch.load(os.path.join(BASE_PATH, 'model_classification_tutorial.pt')))

# %%
images, labels = dataiter.next()
arthopod_types = {0: 'blues', 1: 'classical', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
with torch.no_grad():
    model.eval()
    for ax, image, label in zip(axis.flat,images, labels):
        ax.imshow(img_display(image)) # add image
        image_tensor = image.unsqueeze_(0)
        output_ = model(image_tensor)
        output_ = output_.argmax()
        k = output_.item()==label.item()
        ax.set_title(str(arthopod_types[label.item()])+":" +str(k)) # add label
